# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import missingno as msno

# %%
pd.set_option('display.max_columns',100)
fifa = pd.read_csv("FIFA_data.csv")
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
msno.bar(fifa.iloc[:,0:40])

# %%
msno.bar(fifa.iloc[:,40:])

# %%
pd.set_option('display.max_rows',100)
#Get all the columns where some of the value is null
null_col = {"null_col":[],"null_count":[]}
nullCol = []
for col in fifa.columns:
    null_val = fifa.shape[0] - fifa[col].count()
    if null_val > 0:
        nullCol.append(col)
        null_col["null_col"].append(col)
        null_col["null_count"].append(null_val)

#null_col
null_columns = pd.DataFrame.from_dict(null_col)
null_columns
# Out:
#                     null_col  null_count
# 0                       Club         241
# 1             Preferred Foot          48
# 2   International Reputation          48
# 3                  Weak Foot          48
# 4                Skill Moves          48
# 5                  Work Rate          48
# 6                  Body Type          48
# 7                  Real Face          48
# 8                   Position          60
# 9              Jersey Number          60
# 10                    Joined        1553
# 11               Loaned From       16943
# 12      Contract Valid Until         289
# 13                    Height          48
# 14                    Weight          48
# 15                        LS        2085
# 16                        ST        2085
# 17                        RS        2085
# 18                        LW        2085
# 19                        LF        2085
# 20                        CF        2085
# 21                        RF        2085
# ...

# %%
obj_num_col = fifa.select_dtypes(include=np.number).columns.tolist()
f,ax = plt.subplots(figsize=(25, 15))
sns.heatmap(fifa[obj_num_col].corr(),annot=True, linewidths=0.5,linecolor="green", fmt= '.1f',ax=ax)

# %% [markdown]
# #### Imputation for the number data type; Median value imputation

# %%
for ncol in obj_num_col:
    fifa[ncol].fillna(fifa[ncol].median(),inplace=True)

# %% [markdown]
# #### Imputation for the data type Object; Mode value imputation

# %%
dtyp_obj_nul_col = [
  'Preferred Foot',
  'Work Rate',
  'Body Type',
  'Real Face',
  'Position',
  'Height',
  'Weight',
  'LS',
  'ST',
  'RS',
  'LW',
  'LF',
  'CF',
  'RF',
  'RW',
  'LAM',
  'CAM',
  'RAM',
  'LM',
  'LCM',
  'CM',
  'RCM',
  'RM',
  'LWB',
  'LDM',
  'CDM',
  'RDM',
  'RWB',
  'LB',
  'LCB',
  'CB',
  'RCB',
  'RB']

for col in dtyp_obj_nul_col:
    fifa[col].fillna(fifa[col].mode()[0],inplace=True)

# %%
#Imputing the missing values for the column Club
fifa['Club'].fillna('No Club',inplace=True)

# %%
addtional_col = ['Joined','Loaned From','Contract Valid Until','Release Clause']
for col in addtional_col:
    fifa[col].fillna(0,inplace=True)

# %% [markdown]
# ## Data Visualization

# %%
# functions to get the rounded values from different columns
def defending(data):
    return int(round((data[['Marking', 'StandingTackle', 
                               'SlidingTackle']].mean()).mean()))

def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve', 
                               'BallControl']].mean()).mean()))

def mental(data):
    return int(round((data[['Aggression', 'Interceptions', 'Positioning', 
                               'Vision','Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 
                               'LongPassing']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 
                               'Agility','Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 
                               'Strength']].mean()).mean()))

def rating(data):
    return int(round((data[['Potential', 'Overall']].mean()).mean()))

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy', 
                               'ShotPower','LongShots', 'Penalties']].mean()).mean()))

# %%
# adding these categories to the data

fifa['Defending'] = fifa.apply(defending, axis = 1)
fifa['General'] = fifa.apply(general, axis = 1)
fifa['Mental'] = fifa.apply(mental, axis = 1)
fifa['Passing'] = fifa.apply(passing, axis = 1)
fifa['Mobility'] = fifa.apply(mobility, axis = 1)
fifa['Power'] = fifa.apply(power, axis = 1)
fifa['Rating'] = fifa.apply(rating, axis = 1)
fifa['Shooting'] = fifa.apply(shooting, axis = 1)

# %%
from re import sub
fifa['Wage Amount (€K)'] = fifa['Wage'].apply( lambda x: sub(r'[^\d.]', '', x)).astype('float64')
fifa['Value Amount (€K)'] = fifa['Value'].apply( lambda x: sub(r'[^\d.]', '', x)).astype('float64')

abc = fifa['Height'].apply( lambda x: x.replace("'","."))
fifa['Height in Num'] = abc.apply( lambda x: sub(r'[^\d.]', '', x)).astype('float64')

# %%
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# #### Top 10 potential players with Name, Age, Nationality, Value, Wage and Club

# %%
fifa[['Name','Age','Nationality','Club','Potential','Wage Amount (€K)','Value Amount (€K)']].sort_values(by=['Potential','Wage Amount (€K)','Value Amount (€K)'],ascending=[False,False,False])[0:10]
# Out:
#                   Name  Age Nationality                 Club  Potential  \
# 25           K. Mbappé   19      France  Paris Saint-Germain         95
# 0             L. Messi   31   Argentina         FC Barcelona         94
# 1    Cristiano Ronaldo   33    Portugal             Juventus         94
# 15           P. Dybala   24   Argentina             Juventus         94
# 2            Neymar Jr   26      Brazil  Paris Saint-Germain         93
# 3               De Gea   27       Spain    Manchester United         93
# 9             J. Oblak   25    Slovenia      Atlético Madrid         93
# 229      G. Donnarumma   19       Italy                Milan         93
# 4         K. De Bruyne   27     Belgium      Manchester City         92
# 18       M. ter Stegen   26     Germany         FC Barcelona         92
#
#      Wage Amount (€K)  Value Amount (€K)
# 25              100.0               81.0
# 0               565.0              110.5
# 1               405.0               77.0
# ...

# %% [markdown]
# #### Top 10 highest earning player

# %%
fifa[['Name','Age','Nationality','Club','Potential','Wage Amount (€K)','Value Amount (€K)']].sort_values(by=['Wage Amount (€K)','Value Amount (€K)'],ascending=[False,False])[0:10]
# Out:
#                  Name  Age Nationality             Club  Potential  \
# 0            L. Messi   31   Argentina     FC Barcelona         94
# 7           L. Suárez   31     Uruguay     FC Barcelona         91
# 6           L. Modrić   32     Croatia      Real Madrid         91
# 1   Cristiano Ronaldo   33    Portugal         Juventus         94
# 8        Sergio Ramos   32       Spain      Real Madrid         91
# 4        K. De Bruyne   27     Belgium  Manchester City         92
# 11           T. Kroos   28     Germany      Real Madrid         90
# 36            G. Bale   28       Wales      Real Madrid         88
# 5           E. Hazard   27     Belgium          Chelsea         91
# 32           Coutinho   26      Brazil     FC Barcelona         89
#
#     Wage Amount (€K)  Value Amount (€K)
# 0              565.0              110.5
# 7              455.0               80.0
# 6              420.0               67.0
# 1              405.0               77.0
# ...

# %% [markdown]
# #### Top 10 Club expense in player wages

# %%
Club_Exp = fifa.groupby(['Club'])['Wage Amount (€K)'].sum().nlargest(10).reset_index()
#fig,ax = plt.subplots(figsize=(15,10))
ax=Club_Exp.plot.bar(x='Club',y='Wage Amount (€K)',figsize=(15,10))
plt.ylabel("Expense on Player Wages (€K)")
for i in ax.patches:
    ax.text(i.get_x(),i.get_height()+50, i.get_height(),color='dimgrey')

# %% [markdown]
# #### No of players coming from diffrent country (Top 20)

# %%
#fig,ax = plt.subplots(figsize=(15,10))
no_ply_country = fifa.groupby(['Nationality'])['Name'].count().nlargest(20).reset_index()
no_ply_country.rename(columns={'Name':'Count'},inplace=True)
ax = no_ply_country.plot.bar(x='Nationality',y='Count',figsize=(15,10))
plt.ylabel('No of players')

for i in ax.patches:
    ax.text(i.get_x()-.03, i.get_height()+10,i.get_height(),color='dimgrey')
    #print (i.get_height())
    #ax.text(value,index,str(value))
#for index,value in enumerate(no_ply_country['Name']):
#    plt.text(value,index,str(value))

# %%
best_player = [ 'Overall',
 'Potential',
 'Special',
 'International Reputation',
 'Weak Foot',
 'Skill Moves',
 'Jersey Number',
 'Crossing',
 'Finishing',
 'HeadingAccuracy',
 'ShortPassing',
 'Volleys',
 'Dribbling',
 'Curve',
 'FKAccuracy',
 'LongPassing',
 'BallControl',
 'Acceleration',
 'SprintSpeed',
 'Agility',
 'Reactions',
 'Balance',
 'ShotPower',
 'Jumping',
 'Stamina',
 'Strength',
 'LongShots',
 'Aggression',
 'Interceptions',
 'Positioning',
 'Vision',
 'Penalties',
 'Composure',
 'Marking',
 'StandingTackle',
 'SlidingTackle',
 'GKDiving',
 'GKHandling',
 'GKKicking',
 'GKPositioning',
 'GKReflexes',
 'Defending',
 'General',
 'Mental',
 'Passing',
 'Mobility',
 'Power',
 'Rating',
 'Shooting',
 'Wage Amount (€K)']
for col in best_player:
    print('Best {0} : {1} : prefered foot : {2}'.format(col,fifa.loc[fifa[col].idxmax()]['Name'],fifa.loc[fifa[col].idxmax()]['Preferred Foot']))
# Out:
# Best Overall : L. Messi : prefered foot : Left
# Best Potential : K. Mbappé : prefered foot : Right
# Best Special : L. Suárez : prefered foot : Right
# Best International Reputation : L. Messi : prefered foot : Left
# Best Weak Foot : Neymar Jr : prefered foot : Right
# Best Skill Moves : Cristiano Ronaldo : prefered foot : Right
# Best Jersey Number : Dyego Sousa : prefered foot : Right
# Best Crossing : K. De Bruyne : prefered foot : Right
# Best Finishing : L. Messi : prefered foot : Left
# Best HeadingAccuracy : Naldo : prefered foot : Right
# Best ShortPassing : L. Modrić : prefered foot : Right
# Best Volleys : E. Cavani : prefered foot : Right
# Best Dribbling : L. Messi : prefered foot : Left
# Best Curve : Quaresma : prefered foot : Right
# Best FKAccuracy : L. Messi : prefered foot : Left
# Best LongPassing : T. Kroos : prefered foot : Right
# Best BallControl : L. Messi : prefered foot : Left
# Best Acceleration : Douglas Costa : prefered foot : Left
# ...

# %%
pairplot_col = ['Preferred Foot','Defending',
 'Passing',
 'Power',
 'Shooting',
 'Penalties']
sns.pairplot(fifa[pairplot_col],hue="Preferred Foot")

# %% [markdown]
# #### Position & prefered foot wise players rating and wages

# %%
g = sns.FacetGrid(fifa, col="Position", hue="Preferred Foot",height=3.5, col_wrap=4)
g.map(sns.scatterplot, "Rating", "Wage Amount (€K)", alpha=.7)
g.add_legend()

# %% [markdown]
# #### Position wise No of players available

# %%
pref_foot = fifa.groupby(['Position'])['ID'].count().reset_index()
pref_foot = pref_foot.rename(columns={'ID':'Count'})
ax = pref_foot.plot.bar(x='Position',y='Count',figsize=(15,8))
for i in ax.patches:
    ax.text(i.get_x()-.1,i.get_height()+30,i.get_height())

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
sns.scatterplot(data=fifa,x='Age',y='Wage Amount (€K)')

# %% [markdown]
# #### As per the above scatterplot, Pleyers between 23-32 age are earning more.

# %% [markdown]
# #### Compare performance with Height.

# %%
pairplot_col = ['Defending',
 'Passing',
 'Power',
 'Shooting',
 'Penalties',
 'Overall',
 'Special']
#for col in pairplot_col:
#    sns.scatterplot(data=fifa,x='Height in Num',y=col)
count=1
plt.subplots(figsize=(15, 15))
for i in pairplot_col:
    plt.subplot(len(pairplot_col),1,count)
    #sns.scatterplot(data=fifa,x='Height in Num',y=i)
    sns.boxplot(x = fifa['Height in Num'], y = fifa[i], palette = 'inferno')
    count+=1

# %% [markdown]
# #### Top 10 Left footed player based on Overall performance

# %%
fifa[fifa['Preferred Foot'] == 'Left'].sort_values(by=['Overall'],ascending=False)[['Name','Age','Nationality','Club','International Reputation','Wage']][0:10]
# Out:
#             Name  Age Nationality               Club  \
# 0       L. Messi   31   Argentina       FC Barcelona
# 13   David Silva   32       Spain    Manchester City
# 15     P. Dybala   24   Argentina           Juventus
# 17  A. Griezmann   27      France    Atlético Madrid
# 19   T. Courtois   26     Belgium        Real Madrid
# 24  G. Chiellini   33       Italy           Juventus
# 35       Marcelo   30      Brazil        Real Madrid
# 37     H. Lloris   31      France  Tottenham Hotspur
# 36       G. Bale   28       Wales        Real Madrid
# 28  J. Rodríguez   26    Colombia  FC Bayern München
#
#     International Reputation   Wage
# 0                        5.0  €565K
# 13                       4.0  €285K
# 15                       3.0  €205K
# 17                       4.0  €145K
# 19                       4.0  €240K
# 24                       4.0  €215K
# 35                       4.0  €285K
# 37                       4.0  €150K
# 36                       4.0  €355K
# ...

# %% [markdown]
# #### Top 10 Right footed player based on Overall performance

# %%
fifa[fifa['Preferred Foot'] == 'Right'].sort_values(by=['Overall'],ascending=False)[['Name','Age','Nationality','Club','International Reputation','Wage']][0:10]
# Out:
#                  Name  Age Nationality                 Club  \
# 1   Cristiano Ronaldo   33    Portugal             Juventus
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3              De Gea   27       Spain    Manchester United
# 4        K. De Bruyne   27     Belgium      Manchester City
# 5           E. Hazard   27     Belgium              Chelsea
# 6           L. Modrić   32     Croatia          Real Madrid
# 7           L. Suárez   31     Uruguay         FC Barcelona
# 8        Sergio Ramos   32       Spain          Real Madrid
# 9            J. Oblak   25    Slovenia      Atlético Madrid
# 10     R. Lewandowski   29      Poland    FC Bayern München
#
#     International Reputation   Wage
# 1                        5.0  €405K
# 2                        5.0  €290K
# 3                        4.0  €260K
# 4                        4.0  €355K
# 5                        4.0  €340K
# 6                        4.0  €420K
# 7                        5.0  €455K
# ...
